# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# "running command 'timedatectl' had status 1"
# -- Attaching packages --------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.3.3     v purrr   0.3.4
# v tibble  3.1.0     v dplyr   1.0.5
# v tidyr   1.1.3     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
#
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
covidlies = read_csv("./covid_lies.csv")
# Out:
# -- Column specification --------------------------------------------------------
# cols(
#   misconception_id = col_double(),
#   misconception = col_character(),
#   tweet = col_character(),
#   tweet_id = col_double(),
#   label = col_character()
# )

# %%
# number of tweets by label

covidlies %>%
    count(label)
# Out:
#   label n
# 1 na    6149
# 2 neg    154
# 3 pos    288

# %%
covidlies
# Out:
#      misconception_id
# 1     3
# 2    30
# 3    57
# 4    22
# 5    32
# 6    25
# 7    61
# 8     3
# 9    40
# 10   50
# 11    3
# 12   10
# 13   60
# 14   32
# 15    3
# 16   61
# 17    5
# 18   60
# 19   12
# 20    8
# 21   38
# 22   47
# 23   23
# 24    5
# 25   11
# 26    9
# 27   15
# 28    8
# 29   33
# 30   50
# ...  ...
# 6562 41
# 6563 38
# 6564 62
# 6565 34
# 6566 27
# 6567 30
# 6568 33
# 6569 14
# 6570 23
# 6571 60
# 6572  3
# 6573 25
# 6574  1
# 6575 51
# 6576 52
# 6577 17
# 6578 61
# 6579 43
# 6580 58
# 6581  9
# 6582 31
# 6583 36
# 6584 36
# 6585 34
# 6586 36
# 6587 50
# 6588 19
# 6589 22
# 6590 61
# 6591 25
#      misconception
# 1    Coronavirus is genetically engineered.
# 2    Blowing conch shells destroys coronavirus potency.
# 3    Swans and dolphins swimming in Venice canals following COVID-19 lockdown.
# 4    Cocaine cures coronavirus.
# 5    Observing janata curfew will result in the reduction of covid-19 cases by 40%.
# ...

# %%
# number of tweets by misconception_id FOR "pos" label

covidlies %>%
    filter(label == "pos") %>%
    group_by(misconception_id) %>%
    tally()
# Out:
#    misconception_id n
# 1   1                1
# 2   2                4
# 3   3               42
# 4   4               14
# 5   7                2
# 6   8                3
# 7   9                3
# 8  10               13
# 9  13                1
# 10 14                6
# 11 15               32
# 12 17                1
# 13 18                3
# 14 19                4
# 15 21                1
# 16 23               48
# 17 25               10
# 18 27               37
# 19 28                4
# 20 31                1
# 21 35                1
# 22 36                9
# 23 37                1
# 24 44                3
# 25 49               13
# 26 51               21
# 27 52                1
# 28 53                8
# 29 54                1

# %%
# number of tweets by misconception_id FOR "neg" label

covidlies %>%
    filter(label == "neg") %>%
    group_by(misconception_id) %>%
    tally()
# Out:
#    misconception_id n
# 1   1                2
# 2   3               10
# 3   4                2
# 4   5                1
# 5   8                2
# 6   9                1
# 7  10                3
# 8  11                5
# 9  12                1
# 10 14                9
# 11 15                5
# 12 17                1
# 13 19                1
# 14 21                1
# 15 23                7
# 16 25               21
# 17 30                1
# 18 31                3
# 19 38                1
# 20 43                1
# 21 48                9
# 22 49               12
# 23 50                2
# 24 51               51
# 25 53                1
# 26 55                1

# %%
# number of tweets by misconception_id FOR "na" label

covidlies %>%
    filter(label == "na") %>%
    group_by(misconception_id) %>%
    tally()
# Out:
#     misconception_id n
# 1    1                97
# 2    2                96
# 3    3               234
# 4    4                83
# 5    5                99
# 6    6                99
# 7    7                98
# 8    8                95
# 9    9                96
# 10  10               172
# 11  11                94
# 12  12                99
# 13  13                98
# 14  14                85
# 15  15               108
# 16  16               100
# 17  17                98
# 18  18                97
# 19  19                95
# 20  20               100
# 21  21                98
# 22  22               100
# 23  23                45
# 24  24               100
# 25  25               161
# 26  26               100
# 27  27                63
# 28  28                96
# 29  29               100
# 30  30                99
# ... ...              ...
# 33  33               100
# 34  34               100
# 35  35                99
# 36  36                91
# 37  37                99
# ...

# %%
covidlies %>%
    filter(misconception_id == 29) %>%
    select(misconception) %>%
    unique()
# Out:
#   misconception
# 1 Clapping will kill coronavirus.
